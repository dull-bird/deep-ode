# %% [markdown]
# # <center>The Simplest Example: Solving 1-dim first-order ODE</center>
# <center>DAI, Zhiwen</center>
#
# We just solve the simplest ODE:
# \begin{align}
#     \frac{df}{dx} &= 1,\\
#     f(0) &= 0.
# \end{align}
#
# The unique solution is simply $f(x) = x$.
#
# We use a neural network $\text{net}(x)$ to approximate $f(x)$ and focus on the area $[0, 1]$.

# %%
import torch
import numpy as np
from torch.autograd import grad
from torch.autograd.functional import hessian
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate data
#
# $m = 10000$.

# %%
m = 100

t = np.random.rand(m,1)
x = np.random.rand(m,1)

t = torch.tensor(t, requires_grad=True).float()
x = torch.tensor(x, requires_grad=True).float()

z = torch.cat((t,x), axis=1) # z is (t, x)

# %% [markdown]
# ## Define Network

# %%
net = torch.nn.Sequential(
    torch.nn.Linear(2, 10),
    torch.nn.ELU(),
    torch.nn.Linear(10, 10),
    torch.nn.ELU(),
    torch.nn.Linear(10, 10),
    torch.nn.ELU(),
    torch.nn.Linear(10, 1),
)

# %%
f = torch.sin

# %% [markdown]
# Draw the initial net output.

# %%
x_test = torch.arange(-1, 2, 0.01).float().view(-1, 1)
t_test = torch.zeros_like(x_test)
z_test = torch.cat((t_test, x_test), axis=1)

# print(x_test)
# plt.ylim([-1,2])
# plt.xlim([-1,2])
plt.vlines([0,1], -1, 2, colors="r", linestyles="dashed", label="x=0 or 1")
# plt.vlines(1, 0, 2, colors="r", linestyles="dashed", label="x=0")
# plt.plot(x_test.detach().numpy(), x_test.detach().numpy(), label="y=x")
plt.plot(x_test.detach().numpy(), net(z_test).detach().numpy(), label="y=net(0, x)")
plt.legend()

# %% [markdown]
# As we can see, this is far from the function $f(x) = x$.

# %% [markdown]
# ## Define Loss Function
#
# The implementaion of `loss()` is a little bit tricky. We use `grad` function to obtain gradients and the use the equation that
#
# $$ \nabla_x\sum_{i=1}^{m} \text{net}(x_i) = \left[\frac{d \text{net}(x_i)}{d x_i}\right]_{i=1,...,m},$$
#
# where $x = [x_1,...,x_m]$ to fasten the computation of gradients. We also need to set the flag `create_graph=True` for training.
#
# The loss consists of two parts:
#
# - gradients part: $l_1 = \Vert \frac{d \text{net}(x)}{d x} - 1 \Vert^2$,
# - boundary condition: $l_1 = \Vert \text{net}(0) \Vert^2$.
#
# We all use MSE since it is easy to train.

# %%
def loss(net, z, c=1):
    # first-order condition: 

    # slow way of computing gradient
    l = 0
    # for i in range(len(x)):
    #     x_i = x[i]
    #     l += (grad(net(x_i), x_i, create_graph=True)[0] - 1)**2
    # l /= len(x)
    

    # fast way of computing gradient

    # temp = torch.sum((net(z)))
    # print(temp)

    # tmp = hessian(net, z, create_graph=True)
    # print(tmp)

    # l = torch.sum((grad(torch.sum((net(z))), z, create_graph=True)[0] - 1)**2) / x.shape[0]
    # g1 = grad(torch.sum((net(z))), z, create_graph=True)[0]
    # print(g1.shape)
    x = z[:, 1:]
    t = z[:, 0:1]

    # i = 0
    # print(grad(torch.sum((net(z))), z, create_graph=True)[0][i,0:1])

    l = sum([( grad(torch.sum((net(z))), z, create_graph=True)[0][i,0:1] 
                - hessian(net, z[i, :], create_graph=True)[1,1] )**2 for i in range(len(z))]) / len(z)
    # print(l)

    # boundaray condition:
    

    zeros = torch.zeros((z.shape[0], 1))
    ones = torch.ones((z.shape[0], 1))
    
    z_xIsZero = torch.cat([t, zeros], dim=1)
    z_xIsOne = torch.cat([t, ones], dim=1)

    z_tIsZero = torch.cat([zeros, x], dim=1)

    l11 = sum((net(z_xIsZero) - 0)**2) / len(z)
    l12 = sum((net(z_xIsOne) - 0)**2) / len(z)

    l2 = sum((net(z_tIsZero) - x * (1-x) )**2) / len(z)

    # l1 = sum((net(x_0) - 0)**2).view(-1) / len(z)
    # print(l1)

    # F = f(x.detach().numpy())

    # partial_t = grad(torch.sum((net(x_0))), x_0, create_graph=True)[0][:,0:1]
    # print(partial_t.shape)
    # print(f(x).shape)
    # l2 = torch.sum(( partial_t - 0 )**2) / z.shape[0]

    # l += 
    print(l)
    print(l11)
    print(l12)
    print(l2)
    return l + l11 + l12 + l2 * 10
    # return l

# test loss
l = loss(net, z)
l
# Out:
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.1096], grad_fn=<DivBackward0>)
# tensor([0.0646], grad_fn=<DivBackward0>)
# tensor([0.2341], grad_fn=<DivBackward0>)
# tensor([2.5158], grad_fn=<AddBackward0>)

# %% [markdown]
# ## Define Optimizer

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.01)

# %% [markdown]
# ## Training

# %%
for step in range(100):
    l = loss(net, z)
    print(step, l.detach().numpy())
    optimizer.zero_grad()
    l.backward()
    optimizer.step()
# Out:
# tensor([0.0069], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 0 [0.01128769]
# tensor([0.0066], grad_fn=<DivBackward0>)
# tensor([0.0007], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 1 [0.01116771]
# tensor([0.0065], grad_fn=<DivBackward0>)
# tensor([0.0011], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 2 [0.01152098]
# tensor([0.0066], grad_fn=<DivBackward0>)
# tensor([0.0010], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# 3 [0.01246809]
# tensor([0.0067], grad_fn=<DivBackward0>)
# tensor([0.0007], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 4 [0.01198551]
# tensor([0.0078], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 5 [0.01218444]
# tensor([0.0076], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 6 [0.01147822]
# tensor([0.0066], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([8.2121e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 7 [0.01035444]
# tensor([0.0065], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 8 [0.01039215]
# tensor([0.0068], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 9 [0.0103142]
# tensor([0.0067], grad_fn=<DivBackward0>)
# tensor([0.0008], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 10 [0.01018413]
# tensor([0.0079], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 11 [0.01110815]
# tensor([0.0083], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([7.3305e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 12 [0.01140974]
# tensor([0.0065], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 13 [0.01059449]
# tensor([0.0068], grad_fn=<DivBackward0>)
# tensor([0.0007], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 14 [0.01143362]
# tensor([0.0070], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 15 [0.01132025]
# tensor([0.0077], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 16 [0.01162019]
# tensor([0.0068], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 17 [0.01126585]
# tensor([0.0065], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([7.7415e-05], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 18 [0.01111278]
# tensor([0.0064], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 19 [0.01020215]
# tensor([0.0067], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 20 [0.00986673]
# tensor([0.0063], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 21 [0.00955667]
# tensor([0.0062], grad_fn=<DivBackward0>)
# tensor([0.0007], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 22 [0.00975401]
# tensor([0.0071], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 23 [0.01023873]
# tensor([0.0065], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 24 [0.01079026]
# tensor([0.0070], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 25 [0.01121562]
# tensor([0.0068], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 26 [0.01129371]
# tensor([0.0077], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([6.9581e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 27 [0.01127391]
# tensor([0.0064], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 28 [0.01042849]
# tensor([0.0060], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 29 [0.00947633]
# tensor([0.0058], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 30 [0.00885601]
# tensor([0.0060], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 31 [0.00920182]
# tensor([0.0061], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([8.0591e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 32 [0.00947783]
# tensor([0.0060], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 33 [0.00959016]
# tensor([0.0061], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([7.4675e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 34 [0.00917434]
# tensor([0.0058], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 35 [0.00874713]
# tensor([0.0057], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 36 [0.00852089]
# tensor([0.0072], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 37 [0.0099477]
# tensor([0.0070], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 38 [0.00955248]
# tensor([0.0088], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([8.4711e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 39 [0.01123002]
# tensor([0.0086], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([8.9301e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 40 [0.01124474]
# tensor([0.0058], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 41 [0.00855193]
# tensor([0.0056], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 42 [0.00849592]
# tensor([0.0083], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 43 [0.01130068]
# tensor([0.0087], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 44 [0.01122707]
# tensor([0.0083], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 45 [0.01093851]
# tensor([0.0078], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 46 [0.01135321]
# tensor([0.0052], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 47 [0.00810757]
# tensor([0.0052], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 48 [0.00811338]
# tensor([0.0075], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 49 [0.01091618]
# tensor([0.0057], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 50 [0.00838482]
# tensor([0.0053], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 51 [0.00890113]
# tensor([0.0073], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 52 [0.01259506]
# tensor([0.0056], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 53 [0.00891877]
# tensor([0.0051], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 54 [0.0088358]
# tensor([0.0070], grad_fn=<DivBackward0>)
# tensor([0.0007], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# 55 [0.01384387]
# tensor([0.0053], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 56 [0.00902687]
# tensor([0.0051], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 57 [0.008615]
# tensor([0.0049], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# 58 [0.01082294]
# tensor([0.0056], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# 59 [0.01016403]
# tensor([0.0068], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([9.4845e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 60 [0.00956111]
# tensor([0.0048], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 61 [0.0074466]
# tensor([0.0053], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 62 [0.00841312]
# tensor([0.0060], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([8.9362e-05], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 63 [0.00917093]
# tensor([0.0058], grad_fn=<DivBackward0>)
# tensor([0.0004], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# 64 [0.00929451]
# tensor([0.0049], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 65 [0.00723474]
# tensor([0.0049], grad_fn=<DivBackward0>)
# tensor([0.0006], grad_fn=<DivBackward0>)
# tensor([0.0005], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 66 [0.00825907]
# tensor([0.0048], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 67 [0.00720695]
# tensor([0.0060], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 68 [0.00815945]
# tensor([0.0055], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 69 [0.00743171]
# tensor([0.0056], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 70 [0.00787183]
# tensor([0.0054], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([7.9347e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 71 [0.00743764]
# tensor([0.0052], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 72 [0.00799308]
# tensor([0.0050], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 73 [0.00742689]
# tensor([0.0050], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 74 [0.00687745]
# tensor([0.0052], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 75 [0.00709888]
# tensor([0.0054], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([5.9653e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 76 [0.00721136]
# tensor([0.0053], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 77 [0.00715591]
# tensor([0.0051], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 78 [0.00678196]
# tensor([0.0051], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 79 [0.00664501]
# tensor([0.0050], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 80 [0.00646906]
# tensor([0.0050], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 81 [0.00693238]
# tensor([0.0049], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 82 [0.00726114]
# tensor([0.0052], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 83 [0.00704713]
# tensor([0.0047], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 84 [0.00649468]
# tensor([0.0046], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 85 [0.00613871]
# tensor([0.0047], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([8.4124e-05], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 86 [0.00627032]
# tensor([0.0045], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 87 [0.00640216]
# tensor([0.0046], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([8.2600e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 88 [0.00662787]
# tensor([0.0045], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 89 [0.00627683]
# tensor([0.0045], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([6.9897e-05], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 90 [0.00598972]
# tensor([0.0044], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 91 [0.0058186]
# tensor([0.0054], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 92 [0.00688069]
# tensor([0.0056], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([4.6362e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 93 [0.00744019]
# tensor([0.0043], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 94 [0.00687392]
# tensor([0.0041], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0003], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 95 [0.00639228]
# tensor([0.0041], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 96 [0.00580926]
# tensor([0.0042], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 97 [0.00615994]
# tensor([0.0044], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# tensor([8.9328e-05], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# 98 [0.00622584]
# tensor([0.0046], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0002], grad_fn=<DivBackward0>)
# tensor([0.0001], grad_fn=<DivBackward0>)
# 99 [0.00638745]

# %% [markdown]
# ## Draw the Results

# %%
def analytical_soln(t, x):
    N = 100
    return sum(4/(np.pi**3 * n**3) * (1 - np.cos(n * np.pi)) * np.sin(n * np.pi * x) * np.exp(- n**2 * np.pi**2 * t) for n in range(1, N+1))

# analytical_soln(0.2,0.2)
x_test = torch.arange(0, 1.01, 0.01)
t_test = torch.arange(0, 1.01, 0.01).view(-1, 1)
# z_test = torch.cat((t_test, x_test), axis=1)

soln = analytical_soln(t_test, x_test)

# %%
# print(t_test)
z_test = torch.cartesian_prod(t_test.view(-1,), x_test.view(-1,))
soln_test = net(z_test).view(101,101).detach().numpy()
# print(z_test)

# print(x_test)
# plt.ylim([-1,2])
# plt.xlim([-1,2])
# plt.vlines([0,1], 0, 0.5, colors="r", linestyles="dashed", label="x=0 or 1")
# plt.hlines(0, 0, 0.5, colors="r", linestyles="dashed", label="x=0")
# plt.plot(x_test.detach().numpy(), x_test.detach().numpy(), label="y=x")

idx = 80

plt.plot(x_test.detach().numpy(), soln_test[idx], label="y=net(0, x)")
plt.plot(x_test.detach().numpy(), soln[idx], label="analytical soln")
plt.legend()

# %% [markdown]
# As we can see, the network approximates well in $[0, 1]$, but loses some generality outside the internal.
